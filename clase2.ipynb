# %% [markdown]
# <a href="https://colab.research.google.com/github/a01722171/visualizacion-de-datos/blob/main/clase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path = "https://raw.githubusercontent.com/tec03/Datasets/main/datasets/Cartwheeldata.csv"

# %%
import pandas as pd

# %%
df = pd.read_csv(path)
df.tail()
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 20  21   23      M            2       Y             1    69.0      67.0
# 21  22   29      M            2       N             0    71.0      70.0
# 22  23   25      M            2       N             0    70.0      68.0
# 23  24   26      M            2       N             0    69.0      71.0
# 24  25   23      F            1       Y             1    65.0      63.0
#
#     CWDistance Complete  CompleteGroup  Score
# 20          66        N              0      2
# 21         101        Y              1      8
# 22          82        Y              1      4
# 23          63        Y              1      5
# 24          67        N              0      3

# %%
cols =df.columns
type(cols)
# Out:
# pandas.core.indexes.base.Index

# %%
df.shape
# Out:
# (25, 12)

# %%
cols = cols.to_list()
type(cols)
# Out:
# list

# %%
cols.sort()

# %%
cols
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %%
df.Height
# Out:
# 0     62.00
# 1     62.00
# 2     66.00
# 3     64.00
# 4     73.00
# 5     75.00
# 6     75.00
# 7     65.00
# 8     74.00
# 9     63.00
# 10    69.50
# 11    62.75
# 12    65.00
# 13    61.50
# 14    73.00
# 15    71.00
# 16    61.50
# 17    66.00
# 18    70.00
# 19    68.00
# 20    69.00
# 21    71.00
# 22    70.00
# 23    69.00
# 24    65.00
# Name: Height, dtype: float64

# %%
type(df.Height)
# Out:
# pandas.core.series.Series

# %%
df["Height"]
# Out:
# 0     62.00
# 1     62.00
# 2     66.00
# 3     64.00
# 4     73.00
# 5     75.00
# 6     75.00
# 7     65.00
# 8     74.00
# 9     63.00
# 10    69.50
# 11    62.75
# 12    65.00
# 13    61.50
# 14    73.00
# 15    71.00
# 16    61.50
# 17    66.00
# 18    70.00
# 19    68.00
# 20    69.00
# 21    71.00
# 22    70.00
# 23    69.00
# 24    65.00
# Name: Height, dtype: float64

# %%
type(df["Height"])
# Out:
# pandas.core.series.Series

# %%
x=df[["Height"]]

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
cols
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %%
df[["Age", "Height"]].head(2)
# Out:
#    Age  Height
# 0   56    62.0
# 1   26    62.0

# %%
cols
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %%
df[["Gender","Glasses","Height"]].head(3)
# Out:
#   Gender Glasses  Height
# 0      F       Y    62.0
# 1      F       Y    62.0
# 2      F       Y    66.0

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
favs = ['Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
       'Height', 'Wingspan', 'CWDistance']

# %%
df[favs]
# Out:
#     Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    56      F            1       Y             1   62.00      61.0
# 1    26      F            1       Y             1   62.00      60.0
# 2    33      F            1       Y             1   66.00      64.0
# 3    39      F            1       N             0   64.00      63.0
# 4    27      M            2       N             0   73.00      75.0
# 5    24      M            2       N             0   75.00      71.0
# 6    28      M            2       N             0   75.00      76.0
# 7    22      F            1       N             0   65.00      62.0
# 8    29      M            2       Y             1   74.00      73.0
# 9    33      F            1       Y             1   63.00      60.0
# 10   30      M            2       Y             1   69.50      66.0
# 11   28      F            1       Y             1   62.75      58.0
# 12   25      F            1       Y             1   65.00      64.5
# 13   23      F            1       N             0   61.50      57.5
# 14   31      M            2       Y             1   73.00      74.0
# 15   26      M            2       Y             1   71.00      72.0
# 16   26      F            1       N             0   61.50      59.5
# 17   27      M            2       N             0   66.00      66.0
# 18   23      M            2       Y             1   70.00      69.0
# 19   24      F            1       Y             1   68.00      66.0
# 20   23      M            2       Y             1   69.00      67.0
# 21   29      M            2       N             0   71.00      70.0
# 22   25      M            2       N             0   70.00      68.0
# 23   26      M            2       N             0   69.00      71.0
# 24   23      F            1       Y             1   65.00      63.0
#
#     CWDistance
# 0           79
# 1           70
# 2           85
# 3           87
# 4           72
# 5           81
# 6          107
# 7           98
# 8          106
# 9           65
# 10          96
# 11          79
# 12          92
# 13          66
# 14          72
# 15         115
# 16          90
# 17          74
# 18          64
# 19          85
# 20          66
# 21         101
# 22          82
# 23          63
# 24          67

# %%
df.index
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %%
df.loc[5:10,"Age":"CWDistance"]
# Out:
#     Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 5    24      M            2       N             0    75.0      71.0
# 6    28      M            2       N             0    75.0      76.0
# 7    22      F            1       N             0    65.0      62.0
# 8    29      M            2       Y             1    74.0      73.0
# 9    33      F            1       Y             1    63.0      60.0
# 10   30      M            2       Y             1    69.5      66.0
#
#     CWDistance
# 5           81
# 6          107
# 7           98
# 8          106
# 9           65
# 10          96

# %%
df.iloc[5:11, 1:9]
# Out:
#     Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 5    24      M            2       N             0    75.0      71.0
# 6    28      M            2       N             0    75.0      76.0
# 7    22      F            1       N             0    65.0      62.0
# 8    29      M            2       Y             1    74.0      73.0
# 9    33      F            1       Y             1    63.0      60.0
# 10   30      M            2       Y             1    69.5      66.0
#
#     CWDistance
# 5           81
# 6          107
# 7           98
# 8          106
# 9           65
# 10          96

# %%
df.loc[5:11,["Age","CWDistance"]]
# Out:
#     Age  CWDistance
# 5    24          81
# 6    28         107
# 7    22          98
# 8    29         106
# 9    33          65
# 10   30          96
# 11   28          79

# %%
df.iloc[5:10, -3:]
# Out:
#   Complete  CompleteGroup  Score
# 5        N              0      3
# 6        Y              1     10
# 7        Y              1      9
# 8        N              0      5
# 9        Y              1      8

# %%
df.Gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df.Height.unique()
# Out:
# array([62.  , 66.  , 64.  , 73.  , 75.  , 65.  , 74.  , 63.  , 69.5 ,
#        62.75, 61.5 , 71.  , 70.  , 68.  , 69.  ])

# %%
df.groupby(["Gender", "Glasses"]).size()
# Out:
# Gender  Glasses
# F       N          4
#         Y          8
# M       N          7
#         Y          6
# dtype: int64

# %%
df[["Gender","Glasses"]].value_counts()
# Out:
# Gender  Glasses
# F       Y          8
# M       N          7
#         Y          6
# F       N          4
# dtype: int64
